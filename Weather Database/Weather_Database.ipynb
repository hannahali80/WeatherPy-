# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\hannah\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\hannah\anaconda3\lib\site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Use the tuple() function to display the latitude and longitude combinations.
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 745

# %%
import requests
requests.__version__
# Out:
# '2.26.0'

# %%
import requests
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
   # Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i > 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
    # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")

# Loop through all the cities in our list.
for i in range(len(cities)):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
# Out:
# Beginning Data Retrieval
# -------------------
# Processing Record 1 of Set 1 | ferrol
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | barrow
# Processing Record 5 of Set 1 | sitka
# Processing Record 6 of Set 1 | varadero
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | the valley
# Processing Record 9 of Set 1 | banda aceh
# Processing Record 10 of Set 1 | grand gaube
# Processing Record 11 of Set 1 | marzuq
# Processing Record 12 of Set 1 | port moresby
# Processing Record 13 of Set 1 | alibag
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 1 | hermanus
# Processing Record 17 of Set 1 | tuktoyaktuk
# Processing Record 18 of Set 1 | severo-kurilsk
# Processing Record 19 of Set 1 | new norfolk
# Processing Record 20 of Set 1 | nikolskoye
# Processing Record 21 of Set 1 | hambantota
# Processing Record 22 of Set 1 | berlevag
# Processing Record 23 of Set 1 | salta
# Processing Record 24 of Set 1 | mayo
# Processing Record 25 of Set 1 | padre bernardo
# Processing Record 26 of Set 1 | victoria
# Processing Record 27 of Set 1 | hilo
# Processing Record 28 of Set 1 | leningradskiy
# Processing Record 29 of Set 1 | hami
# Processing Record 30 of Set 1 | airai
# Processing Record 31 of Set 1 | reyes
# Processing Record 32 of Set 1 | lavaltrie
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | torbay
# Processing Record 35 of Set 1 | sambava
# Processing Record 36 of Set 1 | kudahuvadhoo
# Processing Record 37 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 1 | bluff
# Processing Record 40 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 1 | vila franca do campo
# Processing Record 42 of Set 1 | taunggyi
# Processing Record 43 of Set 1 | kapaa
# Processing Record 44 of Set 1 | shibarghan
# City not found. Skipping...
# Processing Record 45 of Set 1 | jamestown
# Processing Record 46 of Set 1 | san quintin
# Processing Record 47 of Set 1 | yaan
# Processing Record 48 of Set 1 | ponta do sol
# Processing Record 49 of Set 1 | tawang
# Processing Record 50 of Set 1 | saint-philippe
# Processing Record 51 of Set 1 | narsaq
# Processing Record 52 of Set 1 | carutapera
# Processing Record 53 of Set 1 | albany
# Processing Record 54 of Set 1 | geraldton
# Processing Record 55 of Set 1 | kars
# Processing Record 56 of Set 1 | abha
# Processing Record 57 of Set 1 | soloneshnoye
# Processing Record 58 of Set 1 | iwanai
# Processing Record 59 of Set 1 | fairbanks
# Processing Record 60 of Set 1 | santa cruz
# Processing Record 61 of Set 1 | oistins
# Processing Record 62 of Set 1 | pisco
# Processing Record 63 of Set 1 | pevek
# Processing Record 64 of Set 1 | hasaki
# Processing Record 65 of Set 1 | senanga
# Processing Record 66 of Set 1 | outjo
# Processing Record 67 of Set 1 | lagoa
# Processing Record 68 of Set 1 | ngukurr
# City not found. Skipping...
# Processing Record 69 of Set 1 | aksarka
# Processing Record 70 of Set 1 | atuona
# Processing Record 71 of Set 1 | hobart
# Processing Record 72 of Set 1 | tsiroanomandidy
# Processing Record 73 of Set 1 | norman wells
# Processing Record 74 of Set 1 | vaini
# Processing Record 75 of Set 1 | jinka
# Processing Record 76 of Set 1 | bichura
# Processing Record 77 of Set 1 | ruidoso
# Processing Record 78 of Set 1 | saldanha
# Processing Record 79 of Set 1 | sao joao da barra
# Processing Record 80 of Set 1 | hithadhoo
# Processing Record 81 of Set 1 | shelburne
# Processing Record 82 of Set 1 | kodiak
# Processing Record 83 of Set 1 | opuwo
# Processing Record 84 of Set 1 | thompson
# Processing Record 85 of Set 1 | alotau
# City not found. Skipping...
# Processing Record 86 of Set 1 | tura
# Processing Record 87 of Set 1 | gat
# Processing Record 88 of Set 1 | camana
# Processing Record 89 of Set 1 | lumeje
# Processing Record 90 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 91 of Set 1 | ulaanbaatar
# Processing Record 92 of Set 1 | bucerias
# Processing Record 93 of Set 1 | avarua
# Processing Record 94 of Set 1 | mount gambier
# Processing Record 95 of Set 1 | clyde river
# Processing Record 96 of Set 1 | muli
# Processing Record 97 of Set 1 | tshikapa
# Processing Record 98 of Set 1 | liverpool
# Processing Record 99 of Set 1 | tasiilaq
# Processing Record 100 of Set 1 | kavieng
# Processing Record 1 of Set 2 | ashta
# Processing Record 2 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 2 | labutta
# City not found. Skipping...
# Processing Record 4 of Set 2 | san sebastian huehuetenango
# Processing Record 5 of Set 2 | qaanaaq
# Processing Record 6 of Set 2 | burns lake
# Processing Record 7 of Set 2 | bengkulu
# Processing Record 8 of Set 2 | saint-pierre
# Processing Record 9 of Set 2 | bethel
# Processing Record 10 of Set 2 | esperance
# Processing Record 11 of Set 2 | coahuayana
# Processing Record 12 of Set 2 | puerto ayora
# Processing Record 13 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 14 of Set 2 | huilong
# Processing Record 15 of Set 2 | lorengau
# Processing Record 16 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 2 | santa rosa
# Processing Record 19 of Set 2 | kushmurun
# Processing Record 20 of Set 2 | cape town
# Processing Record 21 of Set 2 | igarka
# Processing Record 22 of Set 2 | ribeira grande
# Processing Record 23 of Set 2 | san cristobal
# Processing Record 24 of Set 2 | oga
# Processing Record 25 of Set 2 | longyearbyen
# Processing Record 26 of Set 2 | abdulino
# Processing Record 27 of Set 2 | ancud
# Processing Record 28 of Set 2 | port alfred
# Processing Record 29 of Set 2 | namatanai
# Processing Record 30 of Set 2 | harper
# Processing Record 31 of Set 2 | panaba
# Processing Record 32 of Set 2 | ambon
# Processing Record 33 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 2 | aklavik
# Processing Record 35 of Set 2 | radford
# Processing Record 36 of Set 2 | bredasdorp
# Processing Record 37 of Set 2 | viligili
# City not found. Skipping...
# Processing Record 38 of Set 2 | ugoofaaru
# Processing Record 39 of Set 2 | east london
# Processing Record 40 of Set 2 | derzhavinsk
# Processing Record 41 of Set 2 | burgeo
# Processing Record 42 of Set 2 | ilulissat
# Processing Record 43 of Set 2 | margate
# Processing Record 44 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 2 | port lincoln
# Processing Record 46 of Set 2 | castro
# Processing Record 47 of Set 2 | umm lajj
# Processing Record 48 of Set 2 | bulgan
# Processing Record 49 of Set 2 | natal
# Processing Record 50 of Set 2 | padang
# Processing Record 1 of Set 3 | ahipara
# Processing Record 2 of Set 3 | hellvik
# Processing Record 3 of Set 3 | garzon
# Processing Record 4 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 3 | port blair
# Processing Record 6 of Set 3 | brumado
# Processing Record 7 of Set 3 | kruisfontein
# Processing Record 8 of Set 3 | georgetown
# Processing Record 9 of Set 3 | mana
# Processing Record 10 of Set 3 | pueblo
# Processing Record 11 of Set 3 | hammerfest
# Processing Record 12 of Set 3 | hobyo
# Processing Record 13 of Set 3 | saskylakh
# Processing Record 14 of Set 3 | viedma
# Processing Record 15 of Set 3 | sault sainte marie
# Processing Record 16 of Set 3 | vangaindrano
# Processing Record 17 of Set 3 | warri
# Processing Record 18 of Set 3 | cabo san lucas
# Processing Record 19 of Set 3 | kyren
# Processing Record 20 of Set 3 | koster
# Processing Record 21 of Set 3 | los llanos de aridane
# Processing Record 22 of Set 3 | jinan
# Processing Record 23 of Set 3 | sioux lookout
# Processing Record 24 of Set 3 | karistos
# City not found. Skipping...
# Processing Record 25 of Set 3 | hualmay
# Processing Record 26 of Set 3 | pemberton
# Processing Record 27 of Set 3 | yuli
# Processing Record 28 of Set 3 | mabaruma
# Processing Record 29 of Set 3 | cherskiy
# Processing Record 30 of Set 3 | pocone
# Processing Record 31 of Set 3 | pudozh
# Processing Record 32 of Set 3 | amga
# Processing Record 33 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 34 of Set 3 | fort madison
# Processing Record 35 of Set 3 | coquimbo
# Processing Record 36 of Set 3 | sao filipe
# Processing Record 37 of Set 3 | birao
# Processing Record 38 of Set 3 | luderitz
# Processing Record 39 of Set 3 | butaritari
# Processing Record 40 of Set 3 | chenzhou
# Processing Record 41 of Set 3 | onega
# Processing Record 42 of Set 3 | chuy
# Processing Record 43 of Set 3 | ushtobe
# Processing Record 44 of Set 3 | xuddur
# Processing Record 45 of Set 3 | moerai
# Processing Record 46 of Set 3 | lagunas
# Processing Record 47 of Set 3 | krasnoyarsk-66
# City not found. Skipping...
# Processing Record 48 of Set 3 | port keats
# Processing Record 49 of Set 3 | tiksi
# Processing Record 50 of Set 3 | manta
# Processing Record 1 of Set 4 | khatanga
# Processing Record 2 of Set 4 | itoman
# Processing Record 3 of Set 4 | guthrie
# Processing Record 4 of Set 4 | puteyets
# Processing Record 5 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 4 | jeremie
# Processing Record 7 of Set 4 | katsuura
# Processing Record 8 of Set 4 | nazas
# Processing Record 9 of Set 4 | himora
# City not found. Skipping...
# Processing Record 10 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 11 of Set 4 | mar del plata
# Processing Record 12 of Set 4 | yellowknife
# Processing Record 13 of Set 4 | pundaguitan
# Processing Record 14 of Set 4 | aporawan
# City not found. Skipping...
# Processing Record 15 of Set 4 | puerto del rosario
# Processing Record 16 of Set 4 | kamennomostskiy
# Processing Record 17 of Set 4 | sayyan
# Processing Record 18 of Set 4 | terra nova
# Processing Record 19 of Set 4 | tonj
# Processing Record 20 of Set 4 | provideniya
# Processing Record 21 of Set 4 | high rock
# Processing Record 22 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 23 of Set 4 | koslan
# Processing Record 24 of Set 4 | knysna
# Processing Record 25 of Set 4 | varhaug
# Processing Record 26 of Set 4 | turayf
# Processing Record 27 of Set 4 | college
# Processing Record 28 of Set 4 | egra
# Processing Record 29 of Set 4 | bolonchen
# City not found. Skipping...
# Processing Record 30 of Set 4 | taburi
# City not found. Skipping...
# Processing Record 31 of Set 4 | rawson
# Processing Record 32 of Set 4 | manakara
# Processing Record 33 of Set 4 | lavrentiya
# Processing Record 34 of Set 4 | carnarvon
# Processing Record 35 of Set 4 | arraial do cabo
# Processing Record 36 of Set 4 | araguatins
# City not found. Skipping...
# Processing Record 37 of Set 4 | kuching
# Processing Record 38 of Set 4 | kataysk
# Processing Record 39 of Set 4 | sunndalsora
# Processing Record 40 of Set 4 | mansfield
# Processing Record 41 of Set 4 | kaka
# Processing Record 42 of Set 4 | salalah
# Processing Record 43 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 44 of Set 4 | tiznit
# Processing Record 45 of Set 4 | karratha
# Processing Record 46 of Set 4 | tamandare
# Processing Record 47 of Set 4 | nakatunguru
# Processing Record 48 of Set 4 | abadan
# Processing Record 49 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 50 of Set 4 | sorong
# Processing Record 1 of Set 5 | havre-saint-pierre
# Processing Record 2 of Set 5 | saint anthony
# Processing Record 3 of Set 5 | thinadhoo
# Processing Record 4 of Set 5 | matamoros
# Processing Record 5 of Set 5 | talnakh
# Processing Record 6 of Set 5 | utkivka
# Processing Record 7 of Set 5 | eyl
# Processing Record 8 of Set 5 | olafsvik
# Processing Record 9 of Set 5 | kirundo
# Processing Record 10 of Set 5 | nanortalik
# Processing Record 11 of Set 5 | vila velha
# Processing Record 12 of Set 5 | sept-iles
# Processing Record 13 of Set 5 | lev tolstoy
# Processing Record 14 of Set 5 | kirakira
# Processing Record 15 of Set 5 | ilebo
# Processing Record 16 of Set 5 | buraydah
# Processing Record 17 of Set 5 | olinda
# Processing Record 18 of Set 5 | touros
# Processing Record 19 of Set 5 | kahului
# Processing Record 20 of Set 5 | khash
# Processing Record 21 of Set 5 | port elizabeth
# Processing Record 22 of Set 5 | katobu
# Processing Record 23 of Set 5 | la ronge
# Processing Record 24 of Set 5 | dudinka
# Processing Record 25 of Set 5 | munak
# Processing Record 26 of Set 5 | lompoc
# Processing Record 27 of Set 5 | rivadavia
# Processing Record 28 of Set 5 | lazaro cardenas
# Processing Record 29 of Set 5 | bambanglipuro
# Processing Record 30 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 31 of Set 5 | prata
# Processing Record 32 of Set 5 | neunkirchen
# Processing Record 33 of Set 5 | bodinayakkanur
# Processing Record 34 of Set 5 | vila
# Processing Record 35 of Set 5 | cidreira
# Processing Record 36 of Set 5 | rayon
# Processing Record 37 of Set 5 | chokurdakh
# Processing Record 38 of Set 5 | vao
# Processing Record 39 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 40 of Set 5 | tianpeng
# Processing Record 41 of Set 5 | pakokku
# Processing Record 42 of Set 5 | vestmannaeyjar
# Processing Record 43 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 5 | blagoyevo
# Processing Record 45 of Set 5 | shakhty
# Processing Record 46 of Set 5 | letpadan
# Processing Record 47 of Set 5 | egvekinot
# Processing Record 48 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 49 of Set 5 | baykit
# Processing Record 50 of Set 5 | bambous virieux
# Processing Record 1 of Set 6 | tairua
# Processing Record 2 of Set 6 | kathu
# Processing Record 3 of Set 6 | isangel
# Processing Record 4 of Set 6 | vidalia
# Processing Record 5 of Set 6 | urengoy
# Processing Record 6 of Set 6 | te anau
# Processing Record 7 of Set 6 | price
# Processing Record 8 of Set 6 | zelenoborsk
# Processing Record 9 of Set 6 | fortuna
# Processing Record 10 of Set 6 | sobolevo
# Processing Record 11 of Set 6 | sao lourenco do sul
# Processing Record 12 of Set 6 | husavik
# Processing Record 13 of Set 6 | birjand
# Processing Record 14 of Set 6 | pangai
# Processing Record 15 of Set 6 | nizwa
# Processing Record 16 of Set 6 | san juan
# Processing Record 17 of Set 6 | diamantino
# Processing Record 18 of Set 6 | presidencia roque saenz pena
# Processing Record 19 of Set 6 | kelowna
# Processing Record 20 of Set 6 | caravelas
# Processing Record 21 of Set 6 | mareeba
# Processing Record 22 of Set 6 | spas-demensk
# Processing Record 23 of Set 6 | yulara
# Processing Record 24 of Set 6 | istok
# Processing Record 25 of Set 6 | cameta
# Processing Record 26 of Set 6 | nizhniy tsasuchey
# Processing Record 27 of Set 6 | lata
# Processing Record 28 of Set 6 | bilibino
# Processing Record 29 of Set 6 | yar-sale
# Processing Record 30 of Set 6 | madimba
# Processing Record 31 of Set 6 | tautira
# Processing Record 32 of Set 6 | novyy urengoy
# Processing Record 33 of Set 6 | tuatapere
# Processing Record 34 of Set 6 | taoudenni
# Processing Record 35 of Set 6 | mporokoso
# Processing Record 36 of Set 6 | merauke
# Processing Record 37 of Set 6 | camacha
# Processing Record 38 of Set 6 | imbituba
# Processing Record 39 of Set 6 | meulaboh
# Processing Record 40 of Set 6 | turan
# Processing Record 41 of Set 6 | pangnirtung
# Processing Record 42 of Set 6 | sangar
# Processing Record 43 of Set 6 | dikson
# Processing Record 44 of Set 6 | hope
# Processing Record 45 of Set 6 | sri aman
# Processing Record 46 of Set 6 | sakakah
# Processing Record 47 of Set 6 | kavaratti
# Processing Record 48 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 49 of Set 6 | kaitangata
# Processing Record 50 of Set 6 | bima
# Processing Record 1 of Set 7 | ponta delgada
# Processing Record 2 of Set 7 | seoul
# Processing Record 3 of Set 7 | ayagoz
# Processing Record 4 of Set 7 | eden
# Processing Record 5 of Set 7 | mizdah
# Processing Record 6 of Set 7 | lebu
# Processing Record 7 of Set 7 | pipri
# Processing Record 8 of Set 7 | monteagudo
# Processing Record 9 of Set 7 | clarence town
# Processing Record 10 of Set 7 | bobrovka
# Processing Record 11 of Set 7 | codrington
# Processing Record 12 of Set 7 | quatre cocos
# Processing Record 13 of Set 7 | jinchang
# Processing Record 14 of Set 7 | porto novo
# Processing Record 15 of Set 7 | saint-augustin
# Processing Record 16 of Set 7 | arlit
# Processing Record 17 of Set 7 | waingapu
# Processing Record 18 of Set 7 | tagusao
# Processing Record 19 of Set 7 | brae
# Processing Record 20 of Set 7 | nome
# Processing Record 21 of Set 7 | xingcheng
# Processing Record 22 of Set 7 | vista hermosa
# Processing Record 23 of Set 7 | tilichiki
# Processing Record 24 of Set 7 | ucluelet
# Processing Record 25 of Set 7 | deputatskiy
# Processing Record 26 of Set 7 | jardim
# Processing Record 27 of Set 7 | pedernales
# Processing Record 28 of Set 7 | yanam
# Processing Record 29 of Set 7 | pemba
# Processing Record 30 of Set 7 | maceio
# Processing Record 31 of Set 7 | americus
# Processing Record 32 of Set 7 | yerbogachen
# Processing Record 33 of Set 7 | marrakesh
# Processing Record 34 of Set 7 | ambodifototra
# City not found. Skipping...
# Processing Record 35 of Set 7 | nuuk
# Processing Record 36 of Set 7 | naze
# Processing Record 37 of Set 7 | baruun-urt
# Processing Record 38 of Set 7 | lebanon
# Processing Record 39 of Set 7 | caucaia
# Processing Record 40 of Set 7 | tambul
# City not found. Skipping...
# Processing Record 41 of Set 7 | qaqortoq
# Processing Record 42 of Set 7 | flinders
# Processing Record 43 of Set 7 | maghama
# City not found. Skipping...
# Processing Record 44 of Set 7 | portland
# Processing Record 45 of Set 7 | ituni
# City not found. Skipping...
# Processing Record 46 of Set 7 | tezu
# Processing Record 47 of Set 7 | ceres
# Processing Record 48 of Set 7 | huarmey
# Processing Record 49 of Set 7 | karpathos
# Processing Record 50 of Set 7 | gryazi
# Processing Record 1 of Set 8 | yanchukan
# City not found. Skipping...
# Processing Record 2 of Set 8 | kalmunai
# Processing Record 3 of Set 8 | rupert
# Processing Record 4 of Set 8 | alice springs
# Processing Record 5 of Set 8 | gorontalo
# Processing Record 6 of Set 8 | alofi
# Processing Record 7 of Set 8 | pacific grove
# Processing Record 8 of Set 8 | namwala
# Processing Record 9 of Set 8 | gambo
# Processing Record 10 of Set 8 | north bend
# Processing Record 11 of Set 8 | souillac
# Processing Record 12 of Set 8 | maxixe
# Processing Record 13 of Set 8 | lawan kuda baharu
# City not found. Skipping...
# Processing Record 14 of Set 8 | tawkar
# City not found. Skipping...
# Processing Record 15 of Set 8 | agapovka
# Processing Record 16 of Set 8 | boende
# Processing Record 17 of Set 8 | giyani
# Processing Record 18 of Set 8 | port-cartier
# Processing Record 19 of Set 8 | jalu
# Processing Record 20 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 21 of Set 8 | kiruna
# Processing Record 22 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 23 of Set 8 | yekaterinovka
# Processing Record 24 of Set 8 | canon city
# Processing Record 25 of Set 8 | severnoye
# Processing Record 26 of Set 8 | impfondo
# Processing Record 27 of Set 8 | itajuipe
# Processing Record 28 of Set 8 | lincoln
# Processing Record 29 of Set 8 | bafra
# Processing Record 30 of Set 8 | sabang
# Processing Record 31 of Set 8 | kogon
# Processing Record 32 of Set 8 | liaoyang
# Processing Record 33 of Set 8 | richards bay
# Processing Record 34 of Set 8 | muhos
# Processing Record 35 of Set 8 | general teran
# Processing Record 36 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 37 of Set 8 | maumere
# Processing Record 38 of Set 8 | kalispell
# Processing Record 39 of Set 8 | paamiut
# Processing Record 40 of Set 8 | port hardy
# Processing Record 41 of Set 8 | victor harbor
# Processing Record 42 of Set 8 | fayaoue
# Processing Record 43 of Set 8 | klyuchi
# Processing Record 44 of Set 8 | kropotkin
# Processing Record 45 of Set 8 | hay river
# Processing Record 46 of Set 8 | sanski most
# Processing Record 47 of Set 8 | casper
# Processing Record 48 of Set 8 | melun
# Processing Record 49 of Set 8 | beringovskiy
# Processing Record 50 of Set 8 | rincon
# Processing Record 1 of Set 9 | pemangkat
# Processing Record 2 of Set 9 | ixtapa
# Processing Record 3 of Set 9 | mahebourg
# Processing Record 4 of Set 9 | windsor
# Processing Record 5 of Set 9 | klaksvik
# Processing Record 6 of Set 9 | bonthe
# Processing Record 7 of Set 9 | yarmouth
# Processing Record 8 of Set 9 | mattru
# Processing Record 9 of Set 9 | george town
# Processing Record 10 of Set 9 | sungaipenuh
# Processing Record 11 of Set 9 | talesh
# City not found. Skipping...
# Processing Record 12 of Set 9 | benghazi
# Processing Record 13 of Set 9 | mullaitivu
# City not found. Skipping...
# Processing Record 14 of Set 9 | eydhafushi
# Processing Record 15 of Set 9 | sembe
# Processing Record 16 of Set 9 | marsa matruh
# Processing Record 17 of Set 9 | pamplona
# Processing Record 18 of Set 9 | greenville
# Processing Record 19 of Set 9 | krasnosilka
# Processing Record 20 of Set 9 | port-gentil
# Processing Record 21 of Set 9 | bukachacha
# Processing Record 22 of Set 9 | dalbandin
# Processing Record 23 of Set 9 | komsomolskiy
# Processing Record 24 of Set 9 | fecamp
# Processing Record 25 of Set 9 | ayios matthaios
# City not found. Skipping...
# Processing Record 26 of Set 9 | tual
# Processing Record 27 of Set 9 | burica
# City not found. Skipping...
# Processing Record 28 of Set 9 | kindersley
# Processing Record 29 of Set 9 | fort nelson
# Processing Record 30 of Set 9 | kindu
# Processing Record 31 of Set 9 | manaure
# Processing Record 32 of Set 9 | shache
# Processing Record 33 of Set 9 | sirfa
# City not found. Skipping...
# Processing Record 34 of Set 9 | sinnamary
# Processing Record 35 of Set 9 | rodrigues alves
# Processing Record 36 of Set 9 | gbarnga
# Processing Record 37 of Set 9 | barahona
# Processing Record 38 of Set 9 | hvide sande
# Processing Record 39 of Set 9 | hofn
# Processing Record 40 of Set 9 | havoysund
# Processing Record 41 of Set 9 | xining
# Processing Record 42 of Set 9 | jacareacanga
# Processing Record 43 of Set 9 | jumla
# Processing Record 44 of Set 9 | ust-maya
# Processing Record 45 of Set 9 | farap
# Processing Record 46 of Set 9 | terrace
# Processing Record 47 of Set 9 | den helder
# Processing Record 48 of Set 9 | aloleng
# Processing Record 49 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 50 of Set 9 | puerto madryn
# Processing Record 1 of Set 10 | great falls
# Processing Record 2 of Set 10 | kralendijk
# Processing Record 3 of Set 10 | nam som
# Processing Record 4 of Set 10 | balagansk
# Processing Record 5 of Set 10 | bayir
# Processing Record 6 of Set 10 | kachug
# Processing Record 7 of Set 10 | biak
# Processing Record 8 of Set 10 | camalu
# Processing Record 9 of Set 10 | warrington
# Processing Record 10 of Set 10 | makakilo city
# Processing Record 11 of Set 10 | tottori
# Processing Record 12 of Set 10 | awbari
# Processing Record 13 of Set 10 | gairatganj
# Processing Record 14 of Set 10 | vastervik
# City not found. Skipping...
# Processing Record 15 of Set 10 | sola
# Processing Record 16 of Set 10 | saint-francois
# Processing Record 17 of Set 10 | darhan
# Processing Record 18 of Set 10 | falun
# Processing Record 19 of Set 10 | shellbrook
# Processing Record 20 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 10 | port macquarie
# Processing Record 22 of Set 10 | merritt island
# Processing Record 23 of Set 10 | isabela
# Processing Record 24 of Set 10 | bathsheba
# Processing Record 25 of Set 10 | adrar
# Processing Record 26 of Set 10 | san patricio
# Processing Record 27 of Set 10 | upernavik
# Processing Record 28 of Set 10 | aykhal
# Processing Record 29 of Set 10 | wyndham
# Processing Record 30 of Set 10 | bilma
# Processing Record 31 of Set 10 | saint-joseph
# Processing Record 32 of Set 10 | la palma
# Processing Record 33 of Set 10 | boyolangu
# Processing Record 34 of Set 10 | evensk
# Processing Record 35 of Set 10 | hearst
# Processing Record 36 of Set 10 | yumen
# Processing Record 37 of Set 10 | alexandria
# Processing Record 38 of Set 10 | praia da vitoria
# Processing Record 39 of Set 10 | khani
# Processing Record 40 of Set 10 | sarkand
# Processing Record 41 of Set 10 | mocajuba
# Processing Record 42 of Set 10 | laguna
# Processing Record 43 of Set 10 | olga
# Processing Record 44 of Set 10 | arkhangelos
# City not found. Skipping...
# Processing Record 45 of Set 10 | north battleford
# Processing Record 46 of Set 10 | tres arroyos
# Processing Record 47 of Set 10 | kontagora
# Processing Record 48 of Set 10 | tessalit
# Processing Record 49 of Set 10 | kieta
# Processing Record 50 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 11 | vilyuysk
# Processing Record 2 of Set 11 | andenes
# Processing Record 3 of Set 11 | ayr
# Processing Record 4 of Set 11 | zalari
# Processing Record 5 of Set 11 | kasongo-lunda
# Processing Record 6 of Set 11 | grand baie
# Processing Record 7 of Set 11 | duluth
# Processing Record 8 of Set 11 | qunduz
# Processing Record 9 of Set 11 | kastron
# City not found. Skipping...
# Processing Record 10 of Set 11 | nioro
# Processing Record 11 of Set 11 | estelle
# Processing Record 12 of Set 11 | santa fe
# Processing Record 13 of Set 11 | grindavik
# Processing Record 14 of Set 11 | chicama
# Processing Record 15 of Set 11 | iqaluit
# Processing Record 16 of Set 11 | uttarkashi
# Processing Record 17 of Set 11 | ahmadpur
# Processing Record 18 of Set 11 | koindu
# Processing Record 19 of Set 11 | yining
# Processing Record 20 of Set 11 | ranong
# Processing Record 21 of Set 11 | ankang
# Processing Record 22 of Set 11 | kloulklubed
# Processing Record 23 of Set 11 | bouna
# Processing Record 24 of Set 11 | caxito
# Processing Record 25 of Set 11 | bekesszentandras
# Processing Record 26 of Set 11 | ubinskoye
# Processing Record 27 of Set 11 | umm kaddadah
# Processing Record 28 of Set 11 | ketchikan
# Processing Record 29 of Set 11 | komsomolets
# Processing Record 30 of Set 11 | bollnas
# Processing Record 31 of Set 11 | labe
# Processing Record 32 of Set 11 | umea
# Processing Record 33 of Set 11 | broome
# Processing Record 34 of Set 11 | pitimbu
# Processing Record 35 of Set 11 | chapais
# Processing Record 36 of Set 11 | nguru
# Processing Record 37 of Set 11 | miraflores
# Processing Record 38 of Set 11 | darnah
# Processing Record 39 of Set 11 | washington
# Processing Record 40 of Set 11 | okhotsk
# Processing Record 41 of Set 11 | khandyga
# Processing Record 42 of Set 11 | devils lake
# Processing Record 43 of Set 11 | luwuk
# Processing Record 44 of Set 11 | ouadda
# Processing Record 45 of Set 11 | cap malheureux
# Processing Record 46 of Set 11 | porto walter
# Processing Record 47 of Set 11 | araouane
# Processing Record 48 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 49 of Set 11 | konskie
# Processing Record 50 of Set 11 | nabire
# Processing Record 1 of Set 12 | cascavel
# Processing Record 2 of Set 12 | nouakchott
# Processing Record 3 of Set 12 | leshukonskoye
# Processing Record 4 of Set 12 | sigiriya
# Processing Record 5 of Set 12 | davidson
# Processing Record 6 of Set 12 | vanimo
# Processing Record 7 of Set 12 | illapel
# Processing Record 8 of Set 12 | aqtobe
# Processing Record 9 of Set 12 | san rafael
# Processing Record 10 of Set 12 | maragogi
# Processing Record 11 of Set 12 | uyuni
# Processing Record 12 of Set 12 | oranjemund
# Processing Record 13 of Set 12 | haines junction
# Processing Record 14 of Set 12 | kurumkan
# Processing Record 15 of Set 12 | villazon
# Processing Record 16 of Set 12 | vardo
# Processing Record 17 of Set 12 | south sioux city
# Processing Record 18 of Set 12 | kuloy
# Processing Record 19 of Set 12 | halifax
# Processing Record 20 of Set 12 | shambu
# Processing Record 21 of Set 12 | daru
# Processing Record 22 of Set 12 | hostotipaquillo
# Processing Record 23 of Set 12 | canoa
# Processing Record 24 of Set 12 | show low
# Processing Record 25 of Set 12 | varna
# Processing Record 26 of Set 12 | buala
# Processing Record 27 of Set 12 | yatou
# Processing Record 28 of Set 12 | la rioja
# Processing Record 29 of Set 12 | vargem grande do sul
# Processing Record 30 of Set 12 | funadhoo
# Processing Record 31 of Set 12 | ukiah
# Processing Record 32 of Set 12 | rancho palos verdes
# Processing Record 33 of Set 12 | canavieiras
# Processing Record 34 of Set 12 | chebsara
# Processing Record 35 of Set 12 | santa lucia
# Processing Record 36 of Set 12 | sulangan
# Processing Record 37 of Set 12 | karla
# Processing Record 38 of Set 12 | necochea
# Processing Record 39 of Set 12 | itaituba
# Processing Record 40 of Set 12 | sao miguel do araguaia
# Processing Record 41 of Set 12 | awjilah
# Processing Record 42 of Set 12 | fernley
# Processing Record 43 of Set 12 | pilao arcado
# City not found. Skipping...
# Processing Record 44 of Set 12 | wana
# Processing Record 45 of Set 12 | kondinskoye
# Processing Record 46 of Set 12 | homer
# Processing Record 47 of Set 12 | solhan
# Processing Record 48 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 12 | bud
# Processing Record 50 of Set 12 | markova
# Processing Record 1 of Set 13 | amapa
# Processing Record 2 of Set 13 | svetlogorsk
# Processing Record 3 of Set 13 | krasnoselkup
# Processing Record 4 of Set 13 | pafos
# Processing Record 5 of Set 13 | hirna
# Processing Record 6 of Set 13 | bubaque
# Processing Record 7 of Set 13 | montefiascone
# Processing Record 8 of Set 13 | nouadhibou
# Processing Record 9 of Set 13 | boysun
# Processing Record 10 of Set 13 | faanui
# Processing Record 11 of Set 13 | yialos
# City not found. Skipping...
# Processing Record 12 of Set 13 | altos
# Processing Record 13 of Set 13 | maltahohe
# Processing Record 14 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 15 of Set 13 | westfield
# Processing Record 16 of Set 13 | arroio grande
# Processing Record 17 of Set 13 | altus
# Processing Record 18 of Set 13 | salunayan
# Processing Record 19 of Set 13 | christchurch
# Processing Record 20 of Set 13 | mahadday weyne
# City not found. Skipping...
# Processing Record 21 of Set 13 | san ramon
# Processing Record 22 of Set 13 | iberia
# Processing Record 23 of Set 13 | nyurba
# Processing Record 24 of Set 13 | mulchen
# Processing Record 25 of Set 13 | nyrob
# Processing Record 26 of Set 13 | ladario
# Processing Record 27 of Set 13 | holzkirchen
# Processing Record 28 of Set 13 | saint george
# Processing Record 29 of Set 13 | manicore
# Processing Record 30 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 31 of Set 13 | soyo
# Processing Record 32 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 13 | elbasan
# Processing Record 34 of Set 13 | tonantins
# Processing Record 35 of Set 13 | ostrovnoy
# Processing Record 36 of Set 13 | atbasar
# Processing Record 37 of Set 13 | ust-tsilma
# Processing Record 38 of Set 13 | cayenne
# Processing Record 39 of Set 13 | naryan-mar
# Processing Record 40 of Set 13 | healdsburg
# Processing Record 41 of Set 13 | coihaique
# Processing Record 42 of Set 13 | san policarpo
# Processing Record 43 of Set 13 | bahia honda
# Processing Record 44 of Set 13 | korla
# Processing Record 45 of Set 13 | gangotri
# City not found. Skipping...
# Processing Record 46 of Set 13 | orsha
# Processing Record 47 of Set 13 | tabory
# Processing Record 48 of Set 13 | maniitsoq
# Processing Record 49 of Set 13 | kamenka
# Processing Record 50 of Set 13 | shatsk
# Processing Record 1 of Set 14 | biltine
# Processing Record 2 of Set 14 | salinopolis
# Processing Record 3 of Set 14 | seymchan
# Processing Record 4 of Set 14 | armacao dos buzios
# City not found. Skipping...
# Processing Record 5 of Set 14 | fenoarivo
# Processing Record 6 of Set 14 | polyarnyye zori
# Processing Record 7 of Set 14 | hegang
# Processing Record 8 of Set 14 | ilsede
# Processing Record 9 of Set 14 | luanda
# Processing Record 10 of Set 14 | san jeronimo
# Processing Record 11 of Set 14 | asyut
# Processing Record 12 of Set 14 | sirari
# Processing Record 13 of Set 14 | berbera
# Processing Record 14 of Set 14 | mogok
# Processing Record 15 of Set 14 | waipawa
# Processing Record 16 of Set 14 | joshimath
# Processing Record 17 of Set 14 | esmeraldas
# Processing Record 18 of Set 14 | raduzhnyy
# Processing Record 19 of Set 14 | hamilton
# Processing Record 20 of Set 14 | mordovo
# Processing Record 21 of Set 14 | hvammstangi
# City not found. Skipping...
# Processing Record 22 of Set 14 | half moon bay
# Processing Record 23 of Set 14 | chukhloma
# Processing Record 24 of Set 14 | zalantun
# Processing Record 25 of Set 14 | kawana waters
# City not found. Skipping...
# Processing Record 26 of Set 14 | saint-louis
# Processing Record 27 of Set 14 | formosa
# Processing Record 28 of Set 14 | swan river
# Processing Record 29 of Set 14 | milingimbi
# City not found. Skipping...
# Processing Record 30 of Set 14 | shepsi
# Processing Record 31 of Set 14 | jiaozuo
# Processing Record 32 of Set 14 | la crosse
# Processing Record 33 of Set 14 | noumea
# Processing Record 34 of Set 14 | okha
# Processing Record 35 of Set 14 | oktyabrskoye
# Processing Record 36 of Set 14 | karacakoy
# Processing Record 37 of Set 14 | madawaska
# Processing Record 38 of Set 14 | simbahan
# Processing Record 39 of Set 14 | abnub
# Processing Record 40 of Set 14 | abu samrah
# Processing Record 41 of Set 14 | matay
# Processing Record 42 of Set 14 | don sak
# Processing Record 43 of Set 14 | aranos
# Processing Record 44 of Set 14 | gopalpur
# Processing Record 45 of Set 14 | constantine
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
columns = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]

# %%
city_data_df = city_data_df[columns]

# %%
city_data_df
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Ferrol      ES  43.4832   -8.2369     53.67        86          76
# 1      Busselton      AU -33.6500  115.3333     71.91        33          16
# 2        Rikitea      PF -23.1203 -134.9692     75.85        80          67
# 3         Barrow      US  71.2906 -156.7887     -7.58        84           1
# 4          Sitka      US  57.0531 -135.3300     35.49        64          90
# ..           ...     ...      ...       ...       ...       ...         ...
# 671        Matay      EG  28.4190   30.7792     63.03        55         100
# 672      Don Sak      TH   9.3168   99.6918     87.15        65          53
# 673       Aranos      NA -24.1333   19.1167     77.81        42         100
# 674     Gopalpur      IN  19.2667   84.9167     78.10        61          17
# 675  Constantine      DZ  36.3650    6.6147     42.21        81          67
#
#      Wind Speed      Description
# 0          5.84    broken clouds
# 1         10.60       few clouds
# 2         12.19       light rain
# 3          9.22        clear sky
# 4         17.27       light rain
# ..          ...              ...
# 671        7.29  overcast clouds
# 672       10.51    broken clouds
# 673        7.72  overcast clouds
# 674        9.55       few clouds
# 675       13.35    broken clouds
#
# [676 rows x 9 columns]

# %%
# Create the output file (CSV).
Output_file = city_data_df.to_csv(r"C:\Users\Hannah\OneDrive\Desktop\Challange 6\Weather_Database\WeatherPy_Database.csv")
